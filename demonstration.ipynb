# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardsnj/GlyBerta/blob/main/demonstration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import httpimport, os.path

# !pip install -q transformers

with httpimport.github_repo("edwardsnj", "GlyBerta", ref="main"):
  import glyberta

IUPAC_sequences = "iupacseq.txt"
BASEURL = "https://edwardslab.bmcb.georgetown.edu/~nedwards/dropbox/2tZbwHlPjE/"
if not os.path.exists(IUPAC_sequences):
  # !wget {BASEURL}{IUPAC_sequences}
# !wc -l {IUPAC_sequences}
# !head {IUPAC_sequences}
# Out:
# GlyBerta v1.0.8
# 19621 iupacseq.txt
# Neu5Gc(?2-?)Neu5Gc(?2-?)Gal(?1-?)Glc(?1-
# Gal(?1-4)GlcNAc(?1-?)[Gal(?1-4)GlcNAc(?1-2)]Man(?1-3)[Neu5Ac(?2-6)Gal(?1-4)GlcNAc(?1-2)Man(?1-6)]Man(?1-4)GlcNAc(?1-4)GlcNAc(?1-
# Glc(b1-3)Glc(b1-3)Glc(b1-
# Glc(b1-4)Glc(b1-4)Glc(b1-4)Glc(b1-
# Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-
# GlcNAc(b1-2/4)Man(a1-3)[Man(a1-3/6)Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc(?1-
# Neu5Ac(a2-3/6)Gal(b1-4)GlcNAc(b1-2)Man(a1-3)[Gal(b1-3)Gal(b1-4)GlcNAc(b1-2)[Gal(b1-3)Gal(b1-4)GlcNAc(b1-4)]Man(a1-6)]Man(b1-4)GlcNAc(b1-4)[Fuc(a1-6)]GlcNAc(b1-
# Galf(a1-2)Galf(a1-4)Gal(b1-
# GalNAc(a1-3)[Fuc(a1-2)]Gal(b1-4)GlcNAc(b1-3)[Neu5Gc(a2-6)]GalNAc(a1-
# Gal(b1-3)GalNAc(a1-

# %%
# !rm -rf glyberta-model
glyberta.run(f"train --data {IUPAC_sequences} --epochs 20")
# Out:
# Random seed: 1191726399
# Loaded 19621 sequences from iupacseq.txt
# Train: 15697   Validation: 1962   Test: 1962
# Vocabulary size: 126
# Validation out-of-vocabulary rate: 2/38226 = 0.005%
# Test out-of-vocabulary rate: 0/38712 = 0.000%
# Model parameters: 3,291,774
#     <div>
#
#       <progress value='9820' max='9820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9820/9820 03:32, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.658396</td>
#       <td>1.313160</td>
#       <td>0.600591</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.749031</td>
#       <td>0.646093</td>
#       <td>0.793662</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.568074</td>
#       <td>0.530099</td>
#       <td>0.838616</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.549343</td>
#       <td>0.466962</td>
#       <td>0.853831</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.482426</td>
#       <td>0.426116</td>
#       <td>0.869466</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.463186</td>
#       <td>0.391086</td>
#       <td>0.880710</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.407487</td>
#       <td>0.390606</td>
#       <td>0.882535</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.417417</td>
#       <td>0.363702</td>
#       <td>0.890280</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.398064</td>
#       <td>0.352560</td>
#       <td>0.887548</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.384073</td>
#       <td>0.351099</td>
#       <td>0.894145</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.363721</td>
#       <td>0.339767</td>
#       <td>0.887368</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.338954</td>
#       <td>0.318746</td>
#       <td>0.895815</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.336910</td>
#       <td>0.302993</td>
#       <td>0.905683</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.319432</td>
#       <td>0.304929</td>
#       <td>0.906315</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.300071</td>
#       <td>0.282489</td>
#       <td>0.912387</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.295519</td>
#       <td>0.287513</td>
#       <td>0.907792</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.299462</td>
#       <td>0.279889</td>
#       <td>0.909589</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.301074</td>
#       <td>0.277009</td>
#       <td>0.913354</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.294151</td>
#       <td>0.262456</td>
#       <td>0.913706</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.268298</td>
#       <td>0.266865</td>
#       <td>0.915654</td>
#     </tr>
#   </tbody>
# </table><p>
# [transformers] There were missing keys in the checkpoint model loaded: ['lm_head.decoder.weight', 'lm_head.decoder.bias'].
# Retained best model from epoch 19.0 (validation loss 0.2625, checkpoint ./glyberta-model/checkpoint-9329).
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Epoch</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.268298</td>
#       <td>0.271965</td>
#       <td>20</td>
#       <td>0.910391</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2720
#   perplexity      : 1.3125
#   masked accuracy : 91.0391%
#
# Saved model, tokenizer, and test_metrics.json to ./glyberta-model

# %%
glyberta.run(f"evaluate --output_dir ./glyberta-model --data ./glyberta-model/validation.txt")

glyberta.run(f"evaluate --output_dir ./glyberta-model --data ./glyberta-model/test.txt")
# Out:
# Random seed: 3516474195
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>No log</td>
#       <td>0.273768</td>
#       <td>0</td>
#       <td>0.908948</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2738
#   perplexity      : 1.3149
#   masked accuracy : 90.8948%
# Random seed: 1071116598
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:01]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>No log</td>
#       <td>0.254975</td>
#       <td>0</td>
#       <td>0.917098</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2550
#   perplexity      : 1.2904
#   masked accuracy : 91.7098%
