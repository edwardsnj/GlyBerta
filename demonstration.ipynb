# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardsnj/GlyBerta/blob/main/demonstration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import httpimport, os.path

# !pip install -q transformers

with httpimport.github_repo("edwardsnj", "GlyBerta", ref="main"):
  import glyberta

IUPAC_sequences = "iupacseq.txt"
BASEURL = "https://edwardslab.bmcb.georgetown.edu/~nedwards/dropbox/2tZbwHlPjE/"
if not os.path.exists(IUPAC_sequences):
  # !wget {BASEURL}{IUPAC_sequences}
# !wc -l {IUPAC_sequences}
# !head {IUPAC_sequences}
# Out:
# GlyBerta v1.0.7
# --2026-07-01 15:36:29--  https://edwardslab.bmcb.georgetown.edu/~nedwards/dropbox/2tZbwHlPjE/iupacseq.txt
# Resolving edwardslab.bmcb.georgetown.edu (edwardslab.bmcb.georgetown.edu)... 141.161.14.163
# Connecting to edwardslab.bmcb.georgetown.edu (edwardslab.bmcb.georgetown.edu)|141.161.14.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1771034 (1.7M) [text/plain]
# Saving to: ‘iupacseq.txt’
#
# iupacseq.txt        100%[===================>]   1.69M  4.07MB/s    in 0.4s
#
# 2026-07-01 15:36:37 (4.07 MB/s) - ‘iupacseq.txt’ saved [1771034/1771034]
#
# 19621 iupacseq.txt
# Neu5Gc(?2-?)Neu5Gc(?2-?)Gal(?1-?)Glc(?1-
# Gal(?1-4)GlcNAc(?1-?)[Gal(?1-4)GlcNAc(?1-2)]Man(?1-3)[Neu5Ac(?2-6)Gal(?1-4)GlcNAc(?1-2)Man(?1-6)]Man(?1-4)GlcNAc(?1-4)GlcNAc(?1-
# Glc(b1-3)Glc(b1-3)Glc(b1-
# Glc(b1-4)Glc(b1-4)Glc(b1-4)Glc(b1-
# Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-
# GlcNAc(b1-2/4)Man(a1-3)[Man(a1-3/6)Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc(?1-
# Neu5Ac(a2-3/6)Gal(b1-4)GlcNAc(b1-2)Man(a1-3)[Gal(b1-3)Gal(b1-4)GlcNAc(b1-2)[Gal(b1-3)Gal(b1-4)GlcNAc(b1-4)]Man(a1-6)]Man(b1-4)GlcNAc(b1-4)[Fuc(a1-6)]GlcNAc(b1-
# Galf(a1-2)Galf(a1-4)Gal(b1-
# GalNAc(a1-3)[Fuc(a1-2)]Gal(b1-4)GlcNAc(b1-3)[Neu5Gc(a2-6)]GalNAc(a1-
# Gal(b1-3)GalNAc(a1-

# %%
# !rm -rf glyberta-model
glyberta.run(f"train --data {IUPAC_sequences} --epochs 20")
# Out:
# No --seed provided; using random seed 2997227858 (pass --seed 2997227858 to repeat this run).
# Loaded 19621 sequences from iupacseq.txt
# Train: 15697   Validation: 1962   Test: 1962
# Vocabulary size: 125
# Validation out-of-vocabulary rate: 2/38374 = 0.005%
# Test out-of-vocabulary rate: 2/38492 = 0.005%
# Model parameters: 3,291,517
#     <div>
#
#       <progress value='9820' max='9820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9820/9820 03:33, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.749713</td>
#       <td>1.339794</td>
#       <td>0.606845</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.706587</td>
#       <td>0.619596</td>
#       <td>0.816564</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.582261</td>
#       <td>0.511566</td>
#       <td>0.844804</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.497382</td>
#       <td>0.506104</td>
#       <td>0.849004</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.506987</td>
#       <td>0.418822</td>
#       <td>0.866382</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.474977</td>
#       <td>0.404657</td>
#       <td>0.874586</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.413939</td>
#       <td>0.387835</td>
#       <td>0.882089</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.389659</td>
#       <td>0.365663</td>
#       <td>0.884662</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.389481</td>
#       <td>0.343295</td>
#       <td>0.889806</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.350541</td>
#       <td>0.339268</td>
#       <td>0.892711</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.329317</td>
#       <td>0.313374</td>
#       <td>0.900818</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.349081</td>
#       <td>0.295804</td>
#       <td>0.903608</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.338653</td>
#       <td>0.293782</td>
#       <td>0.903339</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.321658</td>
#       <td>0.296937</td>
#       <td>0.905775</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.327406</td>
#       <td>0.301010</td>
#       <td>0.906905</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.287849</td>
#       <td>0.275773</td>
#       <td>0.912191</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.270670</td>
#       <td>0.282537</td>
#       <td>0.909170</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.270375</td>
#       <td>0.269646</td>
#       <td>0.911770</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.305398</td>
#       <td>0.268525</td>
#       <td>0.910412</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.300746</td>
#       <td>0.253211</td>
#       <td>0.917247</td>
#     </tr>
#   </tbody>
# </table><p>
# [transformers] There were missing keys in the checkpoint model loaded: ['lm_head.decoder.weight', 'lm_head.decoder.bias'].
# Retained best model from epoch 20.0 (validation loss 0.2532, checkpoint ./glyberta-model/checkpoint-9820).
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Epoch</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.300746</td>
#       <td>0.256372</td>
#       <td>20</td>
#       <td>0.912907</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2564
#   perplexity      : 1.2922
#   masked accuracy : 91.2907%
#
# Saved model, tokenizer, and test_metrics.json to ./glyberta-model
# Namespace(command='train', output_dir='./glyberta-model', seed=2997227858, mlm_probability=0.15, batch_size=32, max_len=128, data='iupacseq.txt', test_frac=0.1, epochs=20.0, learning_rate=0.0005, hidden_size=256, num_layers=4, num_heads=4, func=<function cmd_train at 0x7faae826e2a0>)

# %%
glyberta.run(f"evaluate --output_dir ./glyberta-model --data ./glyberta-model/validation.txt")

glyberta.run(f"evaluate --output_dir ./glyberta-model --data ./glyberta-model/test.txt")
# Out:
# No --seed provided; using random seed 1354858641 (pass --seed 1354858641 to repeat this run).
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>No log</td>
#       <td>0.265065</td>
#       <td>0</td>
#       <td>0.912539</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2651
#   perplexity      : 1.3035
#   masked accuracy : 91.2539%
# No --seed provided; using random seed 745019247 (pass --seed 745019247 to repeat this run).
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:01]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#       <th>Masked Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>No log</td>
#       <td>0.294484</td>
#       <td>0</td>
#       <td>0.909475</td>
#     </tr>
#   </tbody>
# </table><p>
# === Test-set evaluation ===
#   loss            : 0.2945
#   perplexity      : 1.3424
#   masked accuracy : 90.9475%
# Namespace(command='evaluate', output_dir='./glyberta-model', seed=745019247, mlm_probability=0.15, batch_size=32, max_len=128, data='./glyberta-model/test.txt', func=<function cmd_evaluate at 0x7faae826df80>)
